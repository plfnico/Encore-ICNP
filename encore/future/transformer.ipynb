# %%
import os
import sys
import time
import numpy as np
import pandas as pd
from tqdm import tqdm
import torch
from torch import nn, Tensor
from torch.nn import functional as F
from torch.utils.data import DataLoader
from collections import Counter
from scipy.spatial.distance import jensenshannon
if '..' not in os.sys.path:os.sys.path.append('..')
from model import EncoreSequential, WeightNLLLoss
from utils.dist import get_probability_distributions_from_sequence,compute_ngram_distribution, compute_js_distance
device = torch.device("cuda:6" if torch.cuda.is_available() else "cpu")

# %%
dataset = 'icbc'
data_dir = f'/mnt/ssd1/hsj/encore/{dataset}'
size_cdf_file = os.path.join(data_dir, f'{dataset}_cdf', f'{dataset}_size_cdf_coarse.csv')
interval_cdf_file = os.path.join(data_dir, f'{dataset}_cdf', f'{dataset}_interval_cdf_coarse.csv')
size_cdf = pd.read_csv(size_cdf_file)
interval_cdf = pd.read_csv(interval_cdf_file)
n_size, n_interval = len(size_cdf), len(interval_cdf)
start_token = n_size * n_interval
print(f'n_size: {n_size}, n_interval: {n_interval}, start_token: {start_token}')
# Out:
# n_size: 30, n_interval: 30, start_token: 900

# %%
def get_trainset(pair_index_file, block_size, n_size, n_interval, min_samples, device):
    pair_index = []
    with open(pair_index_file, 'r') as f:
        lines = f.readlines()
        for line in lines:
            pair_index.append([int(x) for x in line.strip().split(',')])
    
    trainset = []
    seqs = []
    size_probs, interval_probs = [], []
    for i, seq in tqdm(enumerate(pair_index[0:1000])):
        seq_trainset = []
        seq = np.concatenate((seq[:-1], seq[:1]))
        seqs.append(seq)
        size_prob, interval_prob = get_probability_distributions_from_sequence(seq, n_size, n_interval)
        size_probs.append(size_prob)
        interval_probs.append(interval_prob)
        size_seq = seq // n_interval
        permuted_seq = np.random.permutation(size_seq)
        size_pairs = compute_ngram_distribution(size_seq, 2)
        permuted_pairs = compute_ngram_distribution(permuted_seq, 2)
        jsd = compute_js_distance(size_pairs, permuted_pairs) ** 2
        jsd = jsd if jsd > 0.1 else 0.1
        weight = jsd * np.log10(len(seq))

        num_samples = max(min_samples, len(seq) - block_size)
        seq = np.append([start_token], seq)
        for i in range(num_samples):
            index = i % (len(seq) - block_size)
            sequence_block = seq[index:index+block_size]
            target_sequence = seq[index+1:index+block_size+1]
            probs = np.concatenate((size_prob, interval_prob))

            seq_trainset.append([
                torch.from_numpy(sequence_block).long(),
                torch.from_numpy(target_sequence).long(),
                torch.from_numpy(probs).float(),
                torch.tensor([weight]).float()
            ])
        trainset.extend(seq_trainset)
    size_probs, interval_probs = np.array(size_probs), np.array(interval_probs)
    return trainset, size_probs, interval_probs, seqs

block_size = 16
min_samples = 100
pair_index_file = os.path.join(data_dir, f'{dataset}_pair_index.txt')
trainset, size_probs, interval_probs, seqs = get_trainset(pair_index_file, block_size, n_size, n_interval, min_samples, device)
print(f'Trainset size: {len(trainset)}')
# Out:
# 1000it [00:05, 170.07it/s]
# Trainset size: 164246

# %%
# def get_dataloader(trainset, subset_size, batch_size, seed):
#     np.random.seed(seed)  
#     subset_size = min(subset_size, len(trainset))  
#     ran_index = np.random.choice(len(trainset), subset_size, replace=False)
#     subset_trainset = [trainset[i] for i in ran_index]
#     return DataLoader(subset_trainset, batch_size=batch_size, shuffle=True)

# subset_size = 64000
# batch_size = 256
# seed = 0
# train_loader = get_dataloader(trainset, subset_size, batch_size, seed)
# seq_tensor, target_tensor, prob_tensor, weight_tensor = next(iter(train_loader))
# seq_tensor.shape, target_tensor.shape, prob_tensor.shape, weight_tensor.shape

# %%
batch_size = 256
train_loader = DataLoader(trainset, batch_size=batch_size, pin_memory=True)

# %%
def get_model_params(model: nn.Module) -> tuple:
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total_params, trainable_params

model = EncoreSequential(n_size, n_interval, 512, block_size, [128, 256, 512], device).to(device)
get_model_params(model)
# Out:
# (37091844, 37091844)

# %%
seq_tensor, target_tensor, prob_tensor, weight_tensor = next(iter(train_loader))
seq_tensor, target_tensor, prob_tensor, weight_tensor = seq_tensor.to(device), target_tensor.to(device), prob_tensor.to(device), weight_tensor.to(device)
output = model(seq_tensor, prob_tensor)

# %%
model_dir = f'/mnt/ssd1/hsj/encore/{dataset}/model/transformer-01-09/'
model_path = os.path.join(model_dir, f'encore_transformer_200.pt')
if os.path.exists(model_path):
    state_dict = torch.load(model_path)
    # 如果需要移除 `module.` 前缀
    new_state_dict = {}
    for k, v in state_dict.items():
        if k.startswith('module.'):
            new_state_dict[k[len('module.'):]] = v
        else:
            new_state_dict[k] = v
    model.load_state_dict(new_state_dict)
    print(f'Loaded model from {model_path}')
# Out:
# Loaded model from /mnt/ssd1/hsj/encore/icbc/model/transformer-01-09/encore_transformer_200.pt

# %%
def train_epoch(model, train_loader, optimizer, criterion):
    model.train()
    total_loss = 0
    for seq_tensor, target_tensor, prob_tensor, weight_tensor in train_loader:
        seq_tensor, target_tensor, prob_tensor, weight_tensor = seq_tensor.to(device), target_tensor.to(device), prob_tensor.to(device), weight_tensor.to(device)
        optimizer.zero_grad()
        output = model(seq_tensor, prob_tensor)
        loss = criterion(output, target_tensor, weight_tensor)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * len(seq_tensor)
    return total_loss / len(train_loader.dataset)

# %%
criterion = WeightNLLLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
s_time = time.time()
for epoch in range(1, 11):
    # train_loader = get_dataloader(trainset, subset_size, batch_size, epoch)
    loss = train_epoch(model, train_loader, optimizer, criterion)
    print(f'Epoch {epoch}, Loss: {loss:.4f}, Time: {time.time()-s_time:.2f}')
# Out:
# Epoch 1, Loss: 1.2451, Time: 55.51
# Epoch 2, Loss: 1.1301, Time: 112.35
# Epoch 3, Loss: 1.0836, Time: 169.37
# Epoch 4, Loss: 1.0699, Time: 227.54
# Epoch 5, Loss: 1.0333, Time: 287.42
# Epoch 6, Loss: 1.0154, Time: 348.34
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 6
#       3 s_time = time.time()
#       4 for epoch in range(1, 11):
#       5     # train_loader = get_dataloader(trainset, subset_size, batch_size, epoch)
# ----> 6     loss = train_epoch(model, train_loader, optimizer, criterion)
#       7     print(f'Epoch {epoch}, Loss: {loss:.4f}, Time: {time.time()-s_time:.2f}')
#
# Cell In[19], line 11, in train_epoch(model, train_loader, optimizer, criterion)
#       9     loss.backward()
#      10     optimizer.step()
# ---> 11     total_loss += loss.item() * len(seq_tensor)
#      12 return total_loss / len(train_loader.dataset)
#
# KeyboardInterrupt:

# %%
def check_seq_gen(seq_gen, size_prob, interval_prob):
    size_gen = seq_gen // n_interval
    interval_gen = seq_gen % n_interval
    return np.min(size_prob[size_gen]) > 0.0 and np.min(interval_prob[interval_gen]) > 0.0


def generate_sequence(model, size_probs, interval_probs, batch_size, block_size, max_length):
    num_smaples = len(size_probs)
    gen_seqs = []
    for i_batch in range(0, num_smaples, batch_size):
        batch_size_probs = size_probs[i_batch:i_batch+batch_size]
        batch_interval_probs = interval_probs[i_batch:i_batch+batch_size]
        batch_probs = np.concatenate((batch_size_probs, batch_interval_probs), axis=1, dtype=np.float32)
        batch_gen_seqs = [[] for _ in range(len(batch_probs))]
        while np.min([len(seq) for seq in batch_gen_seqs]) < max_length:
            current_start_tokens = np.array([start_token] * len(batch_probs))
            seq_gens = model.generate(batch_probs, current_start_tokens, block_size)
            gen_check = [check_seq_gen(seq_gens[i], batch_size_probs[i], batch_interval_probs[i]) for i in range(len(seq_gens))]
            for i in range(len(seq_gens)):
                if gen_check[i]:
                    batch_gen_seqs[i].extend(seq_gens[i])
                    current_start_tokens[i] = seq_gens[i][-1]
            print(i_batch, np.min([len(seq) for seq in batch_gen_seqs]), end='\r')
        batch_gen_seqs = [seq[:max_length] for seq in batch_gen_seqs]
        gen_seqs.extend(batch_gen_seqs)
        print()
        print(len(gen_seqs))
    return gen_seqs

gen_seqs = generate_sequence(model, size_probs, interval_probs, batch_size, block_size, 1000)
# Out:
# 0 1008
# 256
# 256 1008
# 512
# 512 1008
# 768
# 768 1008
# 1000

# %%
# def check_seq_gen(seq_gen, size_prob, interval_prob):
#     size_gen = seq_gen // n_interval
#     interval_gen = seq_gen % n_interval
#     return np.min(size_prob[size_gen]) > 0.0 and np.min(interval_prob[interval_gen]) > 0.0


# def generate_seq(model, size_prob, interval_prob, block_size, max_length):
#     model.eval()
#     current_start_token = start_token
#     seq = []
#     prob = np.concatenate((size_prob, interval_prob), dtype=np.float32)
#     with torch.no_grad():
#         while len(seq) < max_length:
#             seq_gen = model.generate(prob, current_start_token, block_size)
#             if check_seq_gen(seq_gen, size_prob, interval_prob):
#                 seq.extend(seq_gen)
#                 current_start_token = seq_gen[-1]
#             # print(f'Generated sequence length: {len(seq)}', end='\r')
#         # print()
#     return seq

# %%
# gens = []
# for i in tqdm(range(len(size_probs))):
#     seq = generate_seq(model, size_probs[i], interval_probs[i], block_size, 1000)
#     # print(f'Sequence {i} length: {len(seq)}')
#     gens.append(seq)
# Out:
#   1%|          | 1/100 [00:06<11:23,  6.90s/it]
#   1%|          | 1/100 [00:11<19:46, 11.99s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 3
#       1 gens = []
#       2 for i in tqdm(range(len(size_probs))):
# ----> 3     seq = generate_seq(model, size_probs[i], interval_probs[i], block_size, 1000)
#       4     # print(f'Sequence {i} length: {len(seq)}')
#       5     gens.append(seq)
#
# Cell In[14], line 14, in generate_seq(model, size_prob, interval_prob, block_size, max_length)
#      12 with torch.no_grad():
#      13     while len(seq) < max_length:
# ---> 14         seq_gen = model.generate(prob, current_start_token, block_size)
#      15         if check_seq_gen(seq_gen, size_prob, interval_prob):
#      16             seq.extend(seq_gen)
#
# File ~/workspace/helen/Encore-ToN/encore/model.py:178, in EncoreSequential.generate(self, prob, start_token, max_len)
#     176 memory = self.prob_to_hidden(prob_tensor).unsqueeze(1).repeat(1, x.size(1), 1)
#     177 tgt_mask = self.sequence_decoder.generate_square_subsequent_mask(x.size(1)).to(self.device)
# --> 178 output = self.sequence_decoder(x, memory, tgt_mask)
#     179 output = self.fc(output).squeeze(0)
#     180 logits = F.softmax(output[-1], dim=-1).cpu().detach().numpy()
#
# File ~/anaconda3/envs/helen/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/helen/lib/python3.8/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/workspace/helen/Encore-ToN/encore/model.py:141, in SequenceDecoder.forward(self, x, memory, tgt_mask)
#     139 def forward(self, x, memory, tgt_mask=None):
#     140     x = self.positional_encoding(x)
# --> 141     output = self.transfomer(x, memory, tgt_mask=tgt_mask)
#     142     output = self.fc(output)
#     143     return output
#
# File ~/anaconda3/envs/helen/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/helen/lib/python3.8/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/anaconda3/envs/helen/lib/python3.8/site-packages/torch/nn/modules/transformer.py:460, in TransformerDecoder.forward(self, tgt, memory, tgt_mask, memory_mask, tgt_key_padding_mask, memory_key_padding_mask, tgt_is_causal, memory_is_causal)
#     457 tgt_is_causal = _detect_is_causal_mask(tgt_mask, tgt_is_causal, seq_len)
#     459 for mod in self.layers:
# --> 460     output = mod(output, memory, tgt_mask=tgt_mask,
#     461                  memory_mask=memory_mask,
#     462                  tgt_key_padding_mask=tgt_key_padding_mask,
#     463                  memory_key_padding_mask=memory_key_padding_mask,
#     464                  tgt_is_causal=tgt_is_causal,
#     465                  memory_is_causal=memory_is_causal)
#     467 if self.norm is not None:
#     468     output = self.norm(output)
#
# File ~/anaconda3/envs/helen/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/helen/lib/python3.8/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/anaconda3/envs/helen/lib/python3.8/site-packages/torch/nn/modules/transformer.py:848, in TransformerDecoderLayer.forward(self, tgt, memory, tgt_mask, memory_mask, tgt_key_padding_mask, memory_key_padding_mask, tgt_is_causal, memory_is_causal)
#     846     x = self.norm1(x + self._sa_block(x, tgt_mask, tgt_key_padding_mask, tgt_is_causal))
#     847     x = self.norm2(x + self._mha_block(x, memory, memory_mask, memory_key_padding_mask, memory_is_causal))
# --> 848     x = self.norm3(x + self._ff_block(x))
#     850 return x
#
# File ~/anaconda3/envs/helen/lib/python3.8/site-packages/torch/nn/modules/transformer.py:875, in TransformerDecoderLayer._ff_block(self, x)
#     873 def _ff_block(self, x: Tensor) -> Tensor:
#     874     x = self.linear2(self.dropout(self.activation(self.linear1(x))))
# --> 875     return self.dropout3(x)
#
# File ~/anaconda3/envs/helen/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/helen/lib/python3.8/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/anaconda3/envs/helen/lib/python3.8/site-packages/torch/nn/modules/dropout.py:58, in Dropout.forward(self, input)
#      57 def forward(self, input: Tensor) -> Tensor:
# ---> 58     return F.dropout(input, self.p, self.training, self.inplace)
#
# File ~/anaconda3/envs/helen/lib/python3.8/site-packages/torch/nn/functional.py:1266, in dropout(input, p, training, inplace)
#    1264 if p < 0.0 or p > 1.0:
#    1265     raise ValueError(f"dropout probability has to be between 0 and 1, but got {p}")
# -> 1266 return _VF.dropout_(input, p, training) if inplace else _VF.dropout(input, p, training)
#
# File ~/anaconda3/envs/helen/lib/python3.8/site-packages/torch/_VF.py:26, in VFModule.__getattr__(self, attr)
#      23     super().__init__(name)
#      24     self.vf = torch._C._VariableFunctions
# ---> 26 def __getattr__(self, attr):
#      27     return getattr(self.vf, attr)
#
# KeyboardInterrupt:

# %%
def test_sequence_gen(seq_ori, seq_gen, n_interval):
    seq_ori, seq_gen = np.array(seq_ori), np.array(seq_gen)
    size_seq, interval_seq = seq_ori // n_interval, seq_ori % n_interval
    size_gen, interval_gen = seq_gen // n_interval, seq_gen % n_interval
    ori_size_interval = list(zip(size_seq, interval_seq))
    gen_size_interval = list(zip(size_gen, interval_gen))
    jsds = {}
    ori_size_interval_dist = Counter(ori_size_interval)
    gen_size_interval_dist  = Counter(gen_size_interval)
    jsds['size_interval'] = compute_js_distance(ori_size_interval_dist, gen_size_interval_dist) ** 2
    for n in [2, 3, 4]:
        n_gram_ori = compute_ngram_distribution(size_seq, n)
        n_gram_gen = compute_ngram_distribution(size_gen, n)
        jsds['size_{}'.format(n)] = compute_js_distance(n_gram_ori, n_gram_gen) ** 2
    return jsds

jsds = []
for i in range(1000):
    jsd = test_sequence_gen(seqs[i], gen_seqs[i], n_interval)
    jsds.append(jsd)
    print(f'Sequence {i} JSD: {jsd}')
# Out:
# Sequence 0 JSD: {'size_interval': 0.005819697701083214, 'size_2': 0.0011287798199279425, 'size_3': 0.0017826977831219394, 'size_4': 0.0024258385536060825}
# Sequence 1 JSD: {'size_interval': 0.007076993383931781, 'size_2': 0.0004992656805095407, 'size_3': 0.000649318340534293, 'size_4': 0.0024743483879011126}
# Sequence 2 JSD: {'size_interval': 0.003328599991712988, 'size_2': 0.001379992358299539, 'size_3': 0.002318968011033522, 'size_4': 0.00437766585817431}
# Sequence 3 JSD: {'size_interval': 0.006911237473951004, 'size_2': 0.0010842493096944346, 'size_3': 0.0021685898784508887, 'size_4': 0.005086693847850188}
# Sequence 4 JSD: {'size_interval': 0.009112488439404407, 'size_2': 0.01776009701419041, 'size_3': 0.031482549367689475, 'size_4': 0.045643452738644286}
# Sequence 5 JSD: {'size_interval': 0.0010373067681914243, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 6 JSD: {'size_interval': 0.22329010865722043, 'size_2': 0.2229754452968182, 'size_3': 0.36580452383520856, 'size_4': 0.39601274338349013}
# Sequence 7 JSD: {'size_interval': 0.0028812678165276756, 'size_2': 0.0017683285903009973, 'size_3': 0.00286492294210048, 'size_4': 0.004137969408106168}
# Sequence 8 JSD: {'size_interval': 0.35188948724984304, 'size_2': 0.3083917777811151, 'size_3': 0.38545781303234505, 'size_4': 0.43370010392586167}
# Sequence 9 JSD: {'size_interval': 0.0028300048131009756, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 10 JSD: {'size_interval': 0.14760303796100507, 'size_2': 0.11296225052324448, 'size_3': 0.2450279595481862, 'size_4': 0.31946362485167834}
# Sequence 11 JSD: {'size_interval': 0.01446145662365895, 'size_2': 0.010164914336179654, 'size_3': 0.0170379135043892, 'size_4': 0.023176582797232184}
# Sequence 12 JSD: {'size_interval': 0.0034740051101714827, 'size_2': 0.0007851410783439718, 'size_3': 0.003095408488567942, 'size_4': 0.006441505472024506}
# Sequence 13 JSD: {'size_interval': 0.051539500538865704, 'size_2': 0.05143397071037968, 'size_3': 0.13386558348394526, 'size_4': 0.20131691045687722}
# Sequence 14 JSD: {'size_interval': 0.17765728933416086, 'size_2': 0.23631437780764633, 'size_3': 0.3126161339592799, 'size_4': 0.37275861947764116}
# Sequence 15 JSD: {'size_interval': 0.0012649167549406823, 'size_2': 0.0009649060477697072, 'size_3': 0.0013612391443890914, 'size_4': 0.0016970056190568797}
# Sequence 16 JSD: {'size_interval': 0.004533424311992579, 'size_2': 0.0010552205920459493, 'size_3': 0.002293736076416492, 'size_4': 0.009450583810516716}
# Sequence 17 JSD: {'size_interval': 0.005574025980691303, 'size_2': 0.0008684511581829729, 'size_3': 0.0021752968105039927, 'size_4': 0.0034565505991664244}
# Sequence 18 JSD: {'size_interval': 0.0013985846325564343, 'size_2': 0.0009612120231098765, 'size_3': 0.002151160495804835, 'size_4': 0.0034321565386027262}
# Sequence 19 JSD: {'size_interval': 0.028267965578204813, 'size_2': 0.002158351815048934, 'size_3': 0.0073299392191444575, 'size_4': 0.018844761674584452}
# Sequence 20 JSD: {'size_interval': 0.029760360970172886, 'size_2': 0.021865531506726495, 'size_3': 0.07932495664624667, 'size_4': 0.1234359177074537}
# Sequence 21 JSD: {'size_interval': 0.05421104991047319, 'size_2': 0.056288143450567374, 'size_3': 0.1317291291721318, 'size_4': 0.20249543774471332}
# Sequence 22 JSD: {'size_interval': 0.0063065201822847285, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 23 JSD: {'size_interval': 0.002617409414366042, 'size_2': 9.322410549704455e-05, 'size_3': 0.0001401206145198842, 'size_4': 0.0001872097853913707}
# Sequence 24 JSD: {'size_interval': 0.11018618641676284, 'size_2': 0.08824155350856301, 'size_3': 0.19902346576401164, 'size_4': 0.35797208472305253}
# Sequence 25 JSD: {'size_interval': 0.039999874699781494, 'size_2': 0.012669496284114774, 'size_3': 0.027323155467335613, 'size_4': 0.044335845679364425}
# Sequence 26 JSD: {'size_interval': 0.003518302310908227, 'size_2': 0.0011755198086477927, 'size_3': 0.0018841975874316467, 'size_4': 0.004326943446611341}
# Sequence 27 JSD: {'size_interval': 0.020779455547517662, 'size_2': 0.039883559050195014, 'size_3': 0.07451818299983745, 'size_4': 0.11319635441888945}
# Sequence 28 JSD: {'size_interval': 0.004221514621674601, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 29 JSD: {'size_interval': 0.005030045863865704, 'size_2': 0.0015344728608251723, 'size_3': 0.01065656860598471, 'size_4': 0.022741245863566312}
# Sequence 30 JSD: {'size_interval': 0.0021840593602892033, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 31 JSD: {'size_interval': 0.016909741902857236, 'size_2': 0.008252756284515137, 'size_3': 0.025271065334761256, 'size_4': 0.07788239194853183}
# Sequence 32 JSD: {'size_interval': 0.0631918593873707, 'size_2': 0.035068937725696504, 'size_3': 0.08126038740802105, 'size_4': 0.1560626248120027}
# Sequence 33 JSD: {'size_interval': 0.0038624189849917772, 'size_2': 0.0, 'size_3': 2.2608038183152227e-07, 'size_4': 1.2359504224890665e-06}
# Sequence 34 JSD: {'size_interval': 0.00024638466861126346, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 35 JSD: {'size_interval': 0.003639676531533669, 'size_2': 9.567326841418437e-05, 'size_3': 0.00010548517797794554, 'size_4': 0.0004164697551686758}
# Sequence 36 JSD: {'size_interval': 0.0013131485549206935, 'size_2': 0.0004582770636677782, 'size_3': 0.0006803406287953594, 'size_4': 0.001963142341813386}
# Sequence 37 JSD: {'size_interval': 0.001743828397392361, 'size_2': 0.004334243166835048, 'size_3': 0.008917245803239354, 'size_4': 0.01353570800769977}
# Sequence 38 JSD: {'size_interval': 0.004624822400449859, 'size_2': 0.005397606382418909, 'size_3': 0.008707844753342475, 'size_4': 0.012509561836569373}
# Sequence 39 JSD: {'size_interval': 0.029195514486035024, 'size_2': 0.018281019779867843, 'size_3': 0.043743040514672676, 'size_4': 0.10207145532459155}
# Sequence 40 JSD: {'size_interval': 0.021991783289045715, 'size_2': 0.019043499374933034, 'size_3': 0.022175442535583588, 'size_4': 0.025460047844389745}
# Sequence 41 JSD: {'size_interval': 0.018840177938629073, 'size_2': 0.010181115620026797, 'size_3': 0.013164210328906797, 'size_4': 0.01619787152344514}
# Sequence 42 JSD: {'size_interval': 0.04967969150049897, 'size_2': 0.03813077998829563, 'size_3': 0.11327281340609102, 'size_4': 0.1977584220862583}
# Sequence 43 JSD: {'size_interval': 0.30906248012252385, 'size_2': 0.3544032204800582, 'size_3': 0.4194085368274909, 'size_4': 0.4363483146202831}
# Sequence 44 JSD: {'size_interval': 0.001633805172884944, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 45 JSD: {'size_interval': 0.0009280331413239688, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 46 JSD: {'size_interval': 0.015103353820288642, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 47 JSD: {'size_interval': 0.33740309412083125, 'size_2': 0.3837184790513797, 'size_3': 0.43240647138810673, 'size_4': 0.4486988166405338}
# Sequence 48 JSD: {'size_interval': 0.024900207323750805, 'size_2': 0.012422291185790881, 'size_3': 0.026084596576784212, 'size_4': 0.049010518581365306}
# Sequence 49 JSD: {'size_interval': 0.007042939585142251, 'size_2': 0.0025857920254417043, 'size_3': 0.005558618805617449, 'size_4': 0.008749873508074353}
# Sequence 50 JSD: {'size_interval': 0.005623178728348682, 'size_2': 0.0008377664004627415, 'size_3': 0.0012047298255181377, 'size_4': 0.0017745849518711798}
# Sequence 51 JSD: {'size_interval': 0.008953385415694093, 'size_2': 0.005648651108073094, 'size_3': 0.008167435222039502, 'size_4': 0.01090818658290726}
# Sequence 52 JSD: {'size_interval': 0.005512604166781306, 'size_2': 0.0014874424137922043, 'size_3': 0.0036372451381359995, 'size_4': 0.008529926232566518}
# Sequence 53 JSD: {'size_interval': 0.2207172985562387, 'size_2': 0.2313553153466343, 'size_3': 0.351926262508393, 'size_4': 0.4210796518488122}
# Sequence 54 JSD: {'size_interval': 0.016528260621975908, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 55 JSD: {'size_interval': 0.0015105036495717326, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 56 JSD: {'size_interval': 0.003606030124382924, 'size_2': 0.0004500141829380976, 'size_3': 0.0006756181835552334, 'size_4': 0.0009016215709301293}
# Sequence 57 JSD: {'size_interval': 0.003401316304613746, 'size_2': 0.000325300850804508, 'size_3': 0.00047744944200322673, 'size_4': 0.0008217021130191962}
# Sequence 58 JSD: {'size_interval': 0.005942904975845141, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 59 JSD: {'size_interval': 0.006393820762983504, 'size_2': 0.007598908120804904, 'size_3': 0.011880188337711975, 'size_4': 0.013202944626722958}
# Sequence 60 JSD: {'size_interval': 0.03166643036164412, 'size_2': 0.004102311047774596, 'size_3': 0.007418212851702923, 'size_4': 0.016091452039694306}
# Sequence 61 JSD: {'size_interval': 0.00842967628382468, 'size_2': 0.004756967230350159, 'size_3': 0.007507212958782067, 'size_4': 0.01115493465094546}
# Sequence 62 JSD: {'size_interval': 0.004594626337476657, 'size_2': 0.0021875541448458614, 'size_3': 0.007147860464005886, 'size_4': 0.03929507305938068}
# Sequence 63 JSD: {'size_interval': 0.06322849658816201, 'size_2': 0.05593123551250064, 'size_3': 0.13582653585411975, 'size_4': 0.1936238457091134}
# Sequence 64 JSD: {'size_interval': 0.009420184945577387, 'size_2': 0.0013767438826659231, 'size_3': 0.002992763969646581, 'size_4': 0.008213448088993356}
# Sequence 65 JSD: {'size_interval': 0.013146719019573719, 'size_2': 0.000943042683337678, 'size_3': 0.00260489067918347, 'size_4': 0.007281891777385878}
# Sequence 66 JSD: {'size_interval': 0.002873695346775823, 'size_2': 0.00018957649674379747, 'size_3': 0.0002735168406550577, 'size_4': 0.00035015466677582654}
# Sequence 67 JSD: {'size_interval': 0.007962566399254552, 'size_2': 0.0024194310413183464, 'size_3': 0.0044847169858873, 'size_4': 0.006784046090585499}
# Sequence 68 JSD: {'size_interval': 0.004638825958622246, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 69 JSD: {'size_interval': 0.03523220122711331, 'size_2': 0.041848955777570335, 'size_3': 0.0824720792849776, 'size_4': 0.13815343754267004}
# Sequence 70 JSD: {'size_interval': 0.09030784417096165, 'size_2': 0.03963411654247056, 'size_3': 0.1046820495697604, 'size_4': 0.16651568856800042}
# Sequence 71 JSD: {'size_interval': 0.008525352600265977, 'size_2': 0.0037080474347808497, 'size_3': 0.007727936038657132, 'size_4': 0.011879032801208288}
# Sequence 72 JSD: {'size_interval': 0.030036501621343643, 'size_2': 0.026635096992485237, 'size_3': 0.0481097259964531, 'size_4': 0.07996749426395683}
# Sequence 73 JSD: {'size_interval': 0.006577527585105993, 'size_2': 0.0032068511004674977, 'size_3': 0.004338078565366263, 'size_4': 0.0057026366061142825}
# Sequence 74 JSD: {'size_interval': 0.0026195283323226996, 'size_2': 6.181249509207787e-05, 'size_3': 8.298226603263409e-05, 'size_4': 9.798120005527468e-05}
# Sequence 75 JSD: {'size_interval': 0.2661797167715766, 'size_2': 0.3575795446352639, 'size_3': 0.4603836103417801, 'size_4': 0.4752183920198997}
# Sequence 76 JSD: {'size_interval': 0.11542030051412819, 'size_2': 0.041844968810658925, 'size_3': 0.08815065061619197, 'size_4': 0.1343354433867013}
# Sequence 77 JSD: {'size_interval': 0.010728311565639284, 'size_2': 0.001354189260357531, 'size_3': 0.0072675531883892724, 'size_4': 0.012036574604830104}
# Sequence 78 JSD: {'size_interval': 0.014461188702556308, 'size_2': 0.009945287208245168, 'size_3': 0.014338943272357643, 'size_4': 0.02169298867104212}
# Sequence 79 JSD: {'size_interval': 0.018189033369198724, 'size_2': 0.004421028670681572, 'size_3': 0.008563509833136978, 'size_4': 0.014004429241134212}
# Sequence 80 JSD: {'size_interval': 0.007705063782478025, 'size_2': 0.00029234510480626215, 'size_3': 0.000928211846720626, 'size_4': 0.0015768642448746326}
# Sequence 81 JSD: {'size_interval': 0.007850852380332647, 'size_2': 0.001783878805627419, 'size_3': 0.0026514394697137334, 'size_4': 0.0035182938803838635}
# Sequence 82 JSD: {'size_interval': 0.15118412397057618, 'size_2': 0.15567446591067904, 'size_3': 0.27982887001205276, 'size_4': 0.30739747040070814}
# Sequence 83 JSD: {'size_interval': 0.03662851375815336, 'size_2': 0.044763472750151, 'size_3': 0.06927967537466342, 'size_4': 0.1051361321183854}
# Sequence 84 JSD: {'size_interval': 0.04898820452352772, 'size_2': 0.043216076896283366, 'size_3': 0.13412585749070574, 'size_4': 0.21511174421078608}
# Sequence 85 JSD: {'size_interval': 0.0048276348914995494, 'size_2': 0.0016187938005145133, 'size_3': 0.0035392793726556557, 'size_4': 0.0054491125394492135}
# Sequence 86 JSD: {'size_interval': 0.006044521524827776, 'size_2': 0.0021605305425205874, 'size_3': 0.0037880386655665594, 'size_4': 0.006256683957683471}
# Sequence 87 JSD: {'size_interval': 0.004005486082562967, 'size_2': 4.643996969366533e-05, 'size_3': 0.0002460688596461476, 'size_4': 0.001478288885911958}
# Sequence 88 JSD: {'size_interval': 0.02320932805395175, 'size_2': 0.02660892268432319, 'size_3': 0.06311912444732398, 'size_4': 0.1027226563127758}
# Sequence 89 JSD: {'size_interval': 0.0015467815062398824, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 90 JSD: {'size_interval': 0.01273778044586218, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 91 JSD: {'size_interval': 0.03978645855321323, 'size_2': 0.02003872121071037, 'size_3': 0.03608399580979971, 'size_4': 0.05122963832854447}
# Sequence 92 JSD: {'size_interval': 0.00177178513102603, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 93 JSD: {'size_interval': 0.0033722105670867656, 'size_2': 7.993435038079106e-05, 'size_3': 8.2618003816718e-05, 'size_4': 6.704581094260566e-05}
# Sequence 94 JSD: {'size_interval': 0.02078947528452008, 'size_2': 0.012367229241584832, 'size_3': 0.016111059517808425, 'size_4': 0.02650001222543343}
# Sequence 95 JSD: {'size_interval': 0.005645664263170341, 'size_2': 0.00052994441564924, 'size_3': 0.001179631981965595, 'size_4': 0.0016010373428208755}
# Sequence 96 JSD: {'size_interval': 0.05152480085910114, 'size_2': 0.05797894651300683, 'size_3': 0.11077846643636621, 'size_4': 0.17771799691693824}
# Sequence 97 JSD: {'size_interval': 0.2944101558482, 'size_2': 0.2954742086300391, 'size_3': 0.3725638077070085, 'size_4': 0.41500275729548164}
# Sequence 98 JSD: {'size_interval': 0.0012577064497370377, 'size_2': 0.0014521363419662714, 'size_3': 0.002723707097321998, 'size_4': 0.0038405337007977923}
# Sequence 99 JSD: {'size_interval': 0.001484975290151325, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 100 JSD: {'size_interval': 0.007325958605612466, 'size_2': 0.009335861170416826, 'size_3': 0.01447248818119764, 'size_4': 0.01687477611260721}
# Sequence 101 JSD: {'size_interval': 0.002121586802506889, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 102 JSD: {'size_interval': 0.40690050524020727, 'size_2': 0.3762673678616231, 'size_3': 0.4668541013603592, 'size_4': 0.4973140826871436}
# Sequence 103 JSD: {'size_interval': 0.09607892010755212, 'size_2': 0.09324309585992013, 'size_3': 0.20994432482512715, 'size_4': 0.3184771213481569}
# Sequence 104 JSD: {'size_interval': 0.020818413702781747, 'size_2': 0.018856376672261595, 'size_3': 0.0669859125183924, 'size_4': 0.12678876298034722}
# Sequence 105 JSD: {'size_interval': 0.026444666054488787, 'size_2': 0.01077111271461178, 'size_3': 0.022342807844472977, 'size_4': 0.05749326059429435}
# Sequence 106 JSD: {'size_interval': 0.0012031992888452288, 'size_2': 0.0005627312407986884, 'size_3': 0.0013396231651069386, 'size_4': 0.0027858260712938605}
# Sequence 107 JSD: {'size_interval': 0.003521584193624082, 'size_2': 2.6166186720708116e-05, 'size_3': 0.0004623080524190555, 'size_4': 0.0010011659865231946}
# Sequence 108 JSD: {'size_interval': 0.0020319169615886463, 'size_2': 0.002014854994470493, 'size_3': 0.002954841604194163, 'size_4': 0.004494716112217855}
# Sequence 109 JSD: {'size_interval': 0.0033447026605859733, 'size_2': 0.0018514413322571173, 'size_3': 0.0028372747770428466, 'size_4': 0.003736528242770362}
# Sequence 110 JSD: {'size_interval': 0.010488857455818129, 'size_2': 0.004766014656556007, 'size_3': 0.010484743781950513, 'size_4': 0.021672956688444954}
# Sequence 111 JSD: {'size_interval': 0.028280107422693317, 'size_2': 0.03082646054934289, 'size_3': 0.07594733306060676, 'size_4': 0.12329593672318566}
# Sequence 112 JSD: {'size_interval': 0.0070703931229895295, 'size_2': 0.0005930012061415484, 'size_3': 0.0009006298110222817, 'size_4': 0.0012159458299459808}
# Sequence 113 JSD: {'size_interval': 0.0015056103609864748, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 114 JSD: {'size_interval': 0.0015416461734479546, 'size_2': 1.3659005137132215e-05, 'size_3': 3.470313796373221e-05, 'size_4': 7.141672376549014e-05}
# Sequence 115 JSD: {'size_interval': 0.051365305588694364, 'size_2': 0.047682265880872994, 'size_3': 0.08992780384195298, 'size_4': 0.13301169484015832}
# Sequence 116 JSD: {'size_interval': 0.005138308737191911, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 117 JSD: {'size_interval': 0.008268877254692093, 'size_2': 0.0039903565893849415, 'size_3': 0.006782721033180115, 'size_4': 0.012654463011174781}
# Sequence 118 JSD: {'size_interval': 0.013434427549579627, 'size_2': 0.0007540192728542236, 'size_3': 0.00937745115748457, 'size_4': 0.017376340328194143}
# Sequence 119 JSD: {'size_interval': 0.05743530200620475, 'size_2': 0.031080898954445595, 'size_3': 0.04097104475651212, 'size_4': 0.051636561290275565}
# Sequence 120 JSD: {'size_interval': 0.002026443571397876, 'size_2': 0.0013259819452160122, 'size_3': 0.0032307100022788693, 'size_4': 0.005096958242220286}
# Sequence 121 JSD: {'size_interval': 0.007115203401494245, 'size_2': 0.009694506403387424, 'size_3': 0.01659460510525436, 'size_4': 0.026036104188110268}
# Sequence 122 JSD: {'size_interval': 0.002836428326905386, 'size_2': 0.0001310373710137795, 'size_3': 0.0003059910946999925, 'size_4': 0.00048291065342627047}
# Sequence 123 JSD: {'size_interval': 0.004003961952925867, 'size_2': 0.00035586803236341546, 'size_3': 0.0007331665763254631, 'size_4': 0.001080594671887201}
# Sequence 124 JSD: {'size_interval': 0.34557768714821047, 'size_2': 0.32702613577945866, 'size_3': 0.3898313191093161, 'size_4': 0.42614796532578325}
# Sequence 125 JSD: {'size_interval': 0.26254472841674636, 'size_2': 0.24432260753063834, 'size_3': 0.2647094475960684, 'size_4': 0.2861288369923229}
# Sequence 126 JSD: {'size_interval': 0.003910714448726293, 'size_2': 0.00020902474325303115, 'size_3': 0.0005642199133075854, 'size_4': 0.0009175093448401334}
# Sequence 127 JSD: {'size_interval': 0.2148189222798557, 'size_2': 0.3363712942310522, 'size_3': 0.4078576523786322, 'size_4': 0.42535631358631226}
# Sequence 128 JSD: {'size_interval': 0.06475066221205873, 'size_2': 0.052469065817211114, 'size_3': 0.11163043846530787, 'size_4': 0.17624346593681953}
# Sequence 129 JSD: {'size_interval': 0.018787378682057612, 'size_2': 0.006942744727195693, 'size_3': 0.011662983852838014, 'size_4': 0.016973941635670176}
# Sequence 130 JSD: {'size_interval': 0.010999704635182668, 'size_2': 0.005812100272058672, 'size_3': 0.017904339003079292, 'size_4': 0.04068575586075432}
# Sequence 131 JSD: {'size_interval': 0.0015479422338089384, 'size_2': 0.0005350197453130487, 'size_3': 0.0007317979493893446, 'size_4': 0.0014036740590885912}
# Sequence 132 JSD: {'size_interval': 0.0963511267944647, 'size_2': 0.07660961610259755, 'size_3': 0.11736302328299873, 'size_4': 0.17534169134134}
# Sequence 133 JSD: {'size_interval': 0.009701147110314088, 'size_2': 0.006796995606136067, 'size_3': 0.011678047836505322, 'size_4': 0.01808195010869662}
# Sequence 134 JSD: {'size_interval': 0.003543519172365342, 'size_2': 9.212222851794876e-05, 'size_3': 9.559848756544145e-05, 'size_4': 0.0007781934363688587}
# Sequence 135 JSD: {'size_interval': 0.033967635038299096, 'size_2': 0.014958271028155425, 'size_3': 0.04383806239168806, 'size_4': 0.11255136212406736}
# Sequence 136 JSD: {'size_interval': 0.01735213767470811, 'size_2': 0.006637976161419308, 'size_3': 0.022718788628885375, 'size_4': 0.038055525310449666}
# Sequence 137 JSD: {'size_interval': 0.010558048867229853, 'size_2': 0.0009661983100990141, 'size_3': 0.0030576739652359557, 'size_4': 0.017643074736202257}
# Sequence 138 JSD: {'size_interval': 0.09255347559379339, 'size_2': 0.05536053635743809, 'size_3': 0.06074019965175462, 'size_4': 0.06278985395891272}
# Sequence 139 JSD: {'size_interval': 0.004115837122478418, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 140 JSD: {'size_interval': 0.3723545043266741, 'size_2': 0.3990277213543171, 'size_3': 0.45912323420222184, 'size_4': 0.5072633816809619}
# Sequence 141 JSD: {'size_interval': 0.356569101691792, 'size_2': 0.33386161121843977, 'size_3': 0.40164062641527515, 'size_4': 0.4194335300002439}
# Sequence 142 JSD: {'size_interval': 0.0016844597442442024, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 143 JSD: {'size_interval': 0.022043769597922657, 'size_2': 0.004227730440971179, 'size_3': 0.007138701464545712, 'size_4': 0.011328166567684966}
# Sequence 144 JSD: {'size_interval': 0.020137070877079794, 'size_2': 0.0158739235413714, 'size_3': 0.0577065980582644, 'size_4': 0.15921581002132207}
# Sequence 145 JSD: {'size_interval': 0.003239273555914082, 'size_2': 0.0009204832302418288, 'size_3': 0.0017235104422149003, 'size_4': 0.002792225558417007}
# Sequence 146 JSD: {'size_interval': 0.012971272117892455, 'size_2': 0.002910308790630731, 'size_3': 0.007609042840861015, 'size_4': 0.012551616394317885}
# Sequence 147 JSD: {'size_interval': 0.01037317725743052, 'size_2': 0.0006624183216316621, 'size_3': 0.0017175326731358252, 'size_4': 0.006743722794550795}
# Sequence 148 JSD: {'size_interval': 0.0021719014101509145, 'size_2': 0.00028008288375439526, 'size_3': 0.0003797930887207046, 'size_4': 0.0004117898055309875}
# Sequence 149 JSD: {'size_interval': 0.0028866992811031715, 'size_2': 9.005721271596631e-05, 'size_3': 0.00020478702023608332, 'size_4': 0.00037012538867896885}
# Sequence 150 JSD: {'size_interval': 0.0002419951916915092, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 151 JSD: {'size_interval': 0.008547840062705819, 'size_2': 0.0012266203653721016, 'size_3': 0.002499285615731525, 'size_4': 0.0037855300663706686}
# Sequence 152 JSD: {'size_interval': 0.00892091772904654, 'size_2': 0.0009543800922190774, 'size_3': 0.0015780490593140777, 'size_4': 0.002270148430942635}
# Sequence 153 JSD: {'size_interval': 0.003497302136038413, 'size_2': 0.00012228544834143665, 'size_3': 0.00045107445219944606, 'size_4': 0.0011268968268246724}
# Sequence 154 JSD: {'size_interval': 0.017294906924349394, 'size_2': 0.008922104677999003, 'size_3': 0.022791763884412584, 'size_4': 0.054633067654083205}
# Sequence 155 JSD: {'size_interval': 0.004129258425782747, 'size_2': 0.002103440595209763, 'size_3': 0.003736620648499436, 'size_4': 0.00635818596705752}
# Sequence 156 JSD: {'size_interval': 0.0058518648705906074, 'size_2': 0.003550272622043435, 'size_3': 0.010110238763434082, 'size_4': 0.022922557545018294}
# Sequence 157 JSD: {'size_interval': 0.006237106453322263, 'size_2': 0.0023687101833919345, 'size_3': 0.004243947928405752, 'size_4': 0.007871771008747842}
# Sequence 158 JSD: {'size_interval': 0.00886710235769008, 'size_2': 0.010216979211241813, 'size_3': 0.013643858353161642, 'size_4': 0.017248721947343223}
# Sequence 159 JSD: {'size_interval': 0.008055465567108181, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 160 JSD: {'size_interval': 0.00705355371351077, 'size_2': 0.0007663104405583122, 'size_3': 0.0018171730590352975, 'size_4': 0.0036528565701397717}
# Sequence 161 JSD: {'size_interval': 0.000630074251327467, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 162 JSD: {'size_interval': 0.2195499780758996, 'size_2': 0.23369854509757496, 'size_3': 0.3691261991647009, 'size_4': 0.40139171918084804}
# Sequence 163 JSD: {'size_interval': 0.01937791232112458, 'size_2': 0.013496045185284524, 'size_3': 0.03239058848687363, 'size_4': 0.056948732060229344}
# Sequence 164 JSD: {'size_interval': 0.4836241801286764, 'size_2': 0.40073100477543505, 'size_3': 0.49146558850831235, 'size_4': 0.5189886911515829}
# Sequence 165 JSD: {'size_interval': 0.010963527023207003, 'size_2': 9.894118906921903e-05, 'size_3': 0.00024072339040493498, 'size_4': 0.0013314715459232787}
# Sequence 166 JSD: {'size_interval': 0.019350873527547857, 'size_2': 0.004516321300089518, 'size_3': 0.00714687337809425, 'size_4': 0.009430395807942965}
# Sequence 167 JSD: {'size_interval': 0.004687376210618205, 'size_2': 0.0008468262027783421, 'size_3': 0.0017161754930588911, 'size_4': 0.0030035777093875495}
# Sequence 168 JSD: {'size_interval': 0.0042637089276446475, 'size_2': 0.0014301478010920634, 'size_3': 0.004989133373171911, 'size_4': 0.009184260614241461}
# Sequence 169 JSD: {'size_interval': 0.019309523194921935, 'size_2': 0.0013916756589875596, 'size_3': 0.004283192280645097, 'size_4': 0.0074423559281188}
# Sequence 170 JSD: {'size_interval': 0.00323739440125638, 'size_2': 0.0007459786361587278, 'size_3': 0.001982660196294243, 'size_4': 0.005153429051998039}
# Sequence 171 JSD: {'size_interval': 0.018724973431167705, 'size_2': 0.03184113276495628, 'size_3': 0.05831753451962675, 'size_4': 0.09485316667245464}
# Sequence 172 JSD: {'size_interval': 0.03346963190646058, 'size_2': 0.012870706095299651, 'size_3': 0.027034353030825794, 'size_4': 0.048858288897719815}
# Sequence 173 JSD: {'size_interval': 0.009068189821274759, 'size_2': 0.0011346496962458886, 'size_3': 0.004023599444677693, 'size_4': 0.0075894073470052295}
# Sequence 174 JSD: {'size_interval': 0.27709680945640575, 'size_2': 0.3191755409483581, 'size_3': 0.3731931001836161, 'size_4': 0.3922717299833733}
# Sequence 175 JSD: {'size_interval': 0.00723905577763867, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 176 JSD: {'size_interval': 0.038807973980131076, 'size_2': 0.010359592875988368, 'size_3': 0.029611816344732866, 'size_4': 0.05064047129182451}
# Sequence 177 JSD: {'size_interval': 0.009620017723827026, 'size_2': 0.0012638221763658858, 'size_3': 0.008207124083444017, 'size_4': 0.014951112952649944}
# Sequence 178 JSD: {'size_interval': 0.015913627354652078, 'size_2': 0.011874328325170571, 'size_3': 0.01962322174139456, 'size_4': 0.025580699297554958}
# Sequence 179 JSD: {'size_interval': 0.014414788799418076, 'size_2': 0.016117768753476435, 'size_3': 0.024769979115055504, 'size_4': 0.035756975637624915}
# Sequence 180 JSD: {'size_interval': 0.027887587796634514, 'size_2': 0.03180794161869004, 'size_3': 0.06012479033180564, 'size_4': 0.09298502917190311}
# Sequence 181 JSD: {'size_interval': 0.0003999639194917473, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 182 JSD: {'size_interval': 0.0014789159323965032, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 183 JSD: {'size_interval': 0.0024720584671899504, 'size_2': 0.0001473256562577884, 'size_3': 0.0002996796169952784, 'size_4': 0.0005298780514617483}
# Sequence 184 JSD: {'size_interval': 0.015145456435934795, 'size_2': 0.005108302138068333, 'size_3': 0.006383162051804146, 'size_4': 0.007998331221838479}
# Sequence 185 JSD: {'size_interval': 0.162315638874425, 'size_2': 0.11134193973309092, 'size_3': 0.19431446680227352, 'size_4': 0.27999080320337333}
# Sequence 186 JSD: {'size_interval': 0.5219618206243909, 'size_2': 0.5023642996190788, 'size_3': 0.5479528959281049, 'size_4': 0.557519526220247}
# Sequence 187 JSD: {'size_interval': 0.005893367338742677, 'size_2': 7.310146843228453e-05, 'size_3': 0.00015050189536039885, 'size_4': 0.0002549813562371861}
# Sequence 188 JSD: {'size_interval': 0.0039367922007382174, 'size_2': 0.008835540797242067, 'size_3': 0.03924372750500899, 'size_4': 0.08238446592412584}
# Sequence 189 JSD: {'size_interval': 0.0022449921914031675, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 190 JSD: {'size_interval': 0.0012129512086791411, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 191 JSD: {'size_interval': 0.003219152486453765, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 192 JSD: {'size_interval': 0.28657125211597817, 'size_2': 0.35133324357780094, 'size_3': 0.4402162401377563, 'size_4': 0.46584073617682004}
# Sequence 193 JSD: {'size_interval': 0.0038947612900531643, 'size_2': 0.0018330198783296815, 'size_3': 0.0031094252493754876, 'size_4': 0.004958849462061637}
# Sequence 194 JSD: {'size_interval': 0.016976161987587172, 'size_2': 0.004033362791906959, 'size_3': 0.005729086742700476, 'size_4': 0.008470067429284758}
# Sequence 195 JSD: {'size_interval': 0.0020024715760734255, 'size_2': 0.0007897690362027487, 'size_3': 0.0022575593194171448, 'size_4': 0.005782472139131779}
# Sequence 196 JSD: {'size_interval': 0.2094258527745131, 'size_2': 0.28112454697661027, 'size_3': 0.3842278812669597, 'size_4': 0.41319369097283754}
# Sequence 197 JSD: {'size_interval': 0.16658697198301486, 'size_2': 0.17964055459032754, 'size_3': 0.235921988034727, 'size_4': 0.31758680206309287}
# Sequence 198 JSD: {'size_interval': 0.010729089445413264, 'size_2': 0.009199314107355435, 'size_3': 0.015316796755842957, 'size_4': 0.02444054967398218}
# Sequence 199 JSD: {'size_interval': 0.003841686181573151, 'size_2': 0.00036193144799788495, 'size_3': 0.0008222480929131937, 'size_4': 0.0018867762076969852}
# Sequence 200 JSD: {'size_interval': 0.0044435106943594834, 'size_2': 0.0023931399874881354, 'size_3': 0.0038047084713083673, 'size_4': 0.0053804896709063665}
# Sequence 201 JSD: {'size_interval': 0.0075307210028921845, 'size_2': 0.008634218377377649, 'size_3': 0.013263380650591116, 'size_4': 0.018141549853311355}
# Sequence 202 JSD: {'size_interval': 0.03492175216839, 'size_2': 0.01424070827012043, 'size_3': 0.03170815898169943, 'size_4': 0.046908636487206064}
# Sequence 203 JSD: {'size_interval': 0.0030395038630085715, 'size_2': 9.099343692946922e-07, 'size_3': 7.599406100654875e-07, 'size_4': 0.0024403671103269274}
# Sequence 204 JSD: {'size_interval': 0.0006051126517902099, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 205 JSD: {'size_interval': 0.004608053077655933, 'size_2': 0.003086525456394137, 'size_3': 0.004932906316787613, 'size_4': 0.007259084755938939}
# Sequence 206 JSD: {'size_interval': 0.008187948676725126, 'size_2': 0.0038504725736466317, 'size_3': 0.006059729735181705, 'size_4': 0.008302334602097963}
# Sequence 207 JSD: {'size_interval': 0.14336846325152267, 'size_2': 0.12426341498983492, 'size_3': 0.26954533014328996, 'size_4': 0.3322581845936263}
# Sequence 208 JSD: {'size_interval': 0.113332052359612, 'size_2': 0.11452680497791516, 'size_3': 0.20383309325268023, 'size_4': 0.3419716633166362}
# Sequence 209 JSD: {'size_interval': 0.008939861812584543, 'size_2': 0.007691581893418622, 'size_3': 0.02228153524201039, 'size_4': 0.05467343681543728}
# Sequence 210 JSD: {'size_interval': 0.005069127403875067, 'size_2': 0.0030319115593997648, 'size_3': 0.004795533795522777, 'size_4': 0.008964624661951357}
# Sequence 211 JSD: {'size_interval': 0.334654088760549, 'size_2': 0.3977885581244035, 'size_3': 0.4506309307625735, 'size_4': 0.4652108327912182}
# Sequence 212 JSD: {'size_interval': 0.05485188393246423, 'size_2': 0.034227041616897484, 'size_3': 0.08478094847526893, 'size_4': 0.12386582209382055}
# Sequence 213 JSD: {'size_interval': 0.002415785182581112, 'size_2': 0.0002963530474383832, 'size_3': 0.001285044281779675, 'size_4': 0.002907246739504924}
# Sequence 214 JSD: {'size_interval': 0.0004607032056862301, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 215 JSD: {'size_interval': 0.016021106199985927, 'size_2': 0.017152265769051676, 'size_3': 0.04205307640874313, 'size_4': 0.07219947822130193}
# Sequence 216 JSD: {'size_interval': 0.0028855669097454886, 'size_2': 0.001135185061706482, 'size_3': 0.0016930416275218458, 'size_4': 0.002244082910355826}
# Sequence 217 JSD: {'size_interval': 0.00588343324616191, 'size_2': 0.003635984789278924, 'size_3': 0.005463014468118131, 'size_4': 0.008439848680211722}
# Sequence 218 JSD: {'size_interval': 0.0023634102936296733, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 219 JSD: {'size_interval': 0.00528507384568171, 'size_2': 0.0008447615088146068, 'size_3': 0.0016702996871488455, 'size_4': 0.004164886542656564}
# Sequence 220 JSD: {'size_interval': 0.00571270563350381, 'size_2': 0.002725496551338107, 'size_3': 0.008847623389443822, 'size_4': 0.01442358417866636}
# Sequence 221 JSD: {'size_interval': 0.0020692525399788994, 'size_2': 0.0008485744184682414, 'size_3': 0.000996322052313743, 'size_4': 0.0010693561584698065}
# Sequence 222 JSD: {'size_interval': 0.0086260475489459, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 223 JSD: {'size_interval': 0.001549225566246756, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 224 JSD: {'size_interval': 0.00438169890222849, 'size_2': 0.0006253717477659258, 'size_3': 0.003293727563134336, 'size_4': 0.006425710543494613}
# Sequence 225 JSD: {'size_interval': 0.00283685802639247, 'size_2': 0.0014460282319417874, 'size_3': 0.0037893258121688717, 'size_4': 0.006627119969985846}
# Sequence 226 JSD: {'size_interval': 0.005349662176073278, 'size_2': 0.0029610870641866775, 'size_3': 0.006309985604474199, 'size_4': 0.009939278239402667}
# Sequence 227 JSD: {'size_interval': 0.025130418874370716, 'size_2': 0.009648264490575533, 'size_3': 0.01837780434441446, 'size_4': 0.03286225762241451}
# Sequence 228 JSD: {'size_interval': 0.010159570320995683, 'size_2': 0.006081942628330964, 'size_3': 0.014278173186181525, 'size_4': 0.03185489812479235}
# Sequence 229 JSD: {'size_interval': 0.002392066725892969, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 230 JSD: {'size_interval': 0.0029129409622933988, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 231 JSD: {'size_interval': 0.019812939287600848, 'size_2': 0.000880310777379774, 'size_3': 0.0015507037157447394, 'size_4': 0.002424984991296402}
# Sequence 232 JSD: {'size_interval': 0.07486336030996667, 'size_2': 0.043052453393482876, 'size_3': 0.06241526236603644, 'size_4': 0.0903719078211324}
# Sequence 233 JSD: {'size_interval': 0.013420000550699042, 'size_2': 0.0007765698037367252, 'size_3': 0.0030446038405348617, 'size_4': 0.007903985817218307}
# Sequence 234 JSD: {'size_interval': 0.056123373791696206, 'size_2': 0.02273898917926246, 'size_3': 0.03633857025434549, 'size_4': 0.048856883907231995}
# Sequence 235 JSD: {'size_interval': 0.3863045722211668, 'size_2': 0.36419049927567204, 'size_3': 0.4658913614583103, 'size_4': 0.4804292599427966}
# Sequence 236 JSD: {'size_interval': 0.020937823631267484, 'size_2': 0.0025446484936324175, 'size_3': 0.014826971990276147, 'size_4': 0.02528085651957485}
# Sequence 237 JSD: {'size_interval': 0.23307806132670228, 'size_2': 0.2807613832920971, 'size_3': 0.34074428508223353, 'size_4': 0.37163804729073413}
# Sequence 238 JSD: {'size_interval': 0.0020665100315335567, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 239 JSD: {'size_interval': 0.005608119269273835, 'size_2': 0.006387997235549164, 'size_3': 0.010583013370671277, 'size_4': 0.013907957273221852}
# Sequence 240 JSD: {'size_interval': 0.02212192645570879, 'size_2': 0.002416290005513002, 'size_3': 0.00358450123376029, 'size_4': 0.004724970377907186}
# Sequence 241 JSD: {'size_interval': 0.330751723199726, 'size_2': 0.3479393988608457, 'size_3': 0.38979987899271523, 'size_4': 0.43098710817633823}
# Sequence 242 JSD: {'size_interval': 0.00292607530753412, 'size_2': 0.0006943476517461848, 'size_3': 0.001414902549640429, 'size_4': 0.0024033515895064603}
# Sequence 243 JSD: {'size_interval': 0.16797017441594084, 'size_2': 0.08987081361366525, 'size_3': 0.26714270713065114, 'size_4': 0.3550082684230781}
# Sequence 244 JSD: {'size_interval': 0.001348336340464985, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 245 JSD: {'size_interval': 0.021122807216169735, 'size_2': 0.016462648865960442, 'size_3': 0.036813937691954, 'size_4': 0.06227939570093697}
# Sequence 246 JSD: {'size_interval': 0.007644504617257887, 'size_2': 0.004183515479336737, 'size_3': 0.00658272079516656, 'size_4': 0.010805408546094955}
# Sequence 247 JSD: {'size_interval': 0.013710700837856832, 'size_2': 0.004385280006925728, 'size_3': 0.007539505702181266, 'size_4': 0.010712929024007051}
# Sequence 248 JSD: {'size_interval': 0.2690500284792518, 'size_2': 0.28440798634679315, 'size_3': 0.37710538112655423, 'size_4': 0.3960132285969228}
# Sequence 249 JSD: {'size_interval': 0.0031896721782562676, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 250 JSD: {'size_interval': 0.016089865659249688, 'size_2': 0.008868925228112981, 'size_3': 0.015739273139206634, 'size_4': 0.022443030293042718}
# Sequence 251 JSD: {'size_interval': 0.05023937067863207, 'size_2': 0.05427460175498512, 'size_3': 0.10485989632816545, 'size_4': 0.14384590902324831}
# Sequence 252 JSD: {'size_interval': 0.04686439115156852, 'size_2': 0.06715882485994168, 'size_3': 0.10052754371400159, 'size_4': 0.14180110049896222}
# Sequence 253 JSD: {'size_interval': 0.013010519864951706, 'size_2': 0.006908323237345285, 'size_3': 0.011101061913217011, 'size_4': 0.016204524738078537}
# Sequence 254 JSD: {'size_interval': 0.1930693200867246, 'size_2': 0.20536523305211393, 'size_3': 0.28384171384828305, 'size_4': 0.34938982941254626}
# Sequence 255 JSD: {'size_interval': 0.0036465941859160794, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 256 JSD: {'size_interval': 0.3427225183875488, 'size_2': 0.2692656906002623, 'size_3': 0.37802707078729114, 'size_4': 0.43370010392586167}
# Sequence 257 JSD: {'size_interval': 0.007861508695541884, 'size_2': 0.0062765968469723245, 'size_3': 0.011003754902702341, 'size_4': 0.013740648137401126}
# Sequence 258 JSD: {'size_interval': 0.1757175246060156, 'size_2': 0.2527799221876827, 'size_3': 0.3461948993111386, 'size_4': 0.38841687108266315}
# Sequence 259 JSD: {'size_interval': 0.005034165888756722, 'size_2': 0.0003851818992850883, 'size_3': 0.0012298340427557893, 'size_4': 0.002368368364350527}
# Sequence 260 JSD: {'size_interval': 0.009755490413461557, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 261 JSD: {'size_interval': 0.1888797177998455, 'size_2': 0.2321179895356011, 'size_3': 0.26413428436803005, 'size_4': 0.3011468140588254}
# Sequence 262 JSD: {'size_interval': 0.009239764010697551, 'size_2': 0.006194810369941489, 'size_3': 0.008999867793647476, 'size_4': 0.013690072507192907}
# Sequence 263 JSD: {'size_interval': 0.016551245190613743, 'size_2': 0.007353647646943936, 'size_3': 0.030938955228269983, 'size_4': 0.07788950337638643}
# Sequence 264 JSD: {'size_interval': 0.002513728213518559, 'size_2': 1.4872150306977726e-05, 'size_3': 2.3849940979174627e-05, 'size_4': 3.397763726927179e-05}
# Sequence 265 JSD: {'size_interval': 0.006634491842985665, 'size_2': 0.004156649877664002, 'size_3': 0.006548593928367747, 'size_4': 0.008954039123345718}
# Sequence 266 JSD: {'size_interval': 0.010690257761849174, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 267 JSD: {'size_interval': 0.0029898482194891853, 'size_2': 0.003025080939178321, 'size_3': 0.008133592521219701, 'size_4': 0.013826577212991234}
# Sequence 268 JSD: {'size_interval': 0.005490607515297761, 'size_2': 0.0007590932436790168, 'size_3': 0.0013821181464277617, 'size_4': 0.0027307934243417306}
# Sequence 269 JSD: {'size_interval': 0.009319073913199702, 'size_2': 0.0010941519765024093, 'size_3': 0.00184290619775679, 'size_4': 0.003097257865942713}
# Sequence 270 JSD: {'size_interval': 0.003141320743909559, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 271 JSD: {'size_interval': 0.00107405092766921, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 272 JSD: {'size_interval': 0.0077014973069398805, 'size_2': 9.397455933045028e-07, 'size_3': 1.8114560792122658e-06, 'size_4': 2.2732261883423996e-05}
# Sequence 273 JSD: {'size_interval': 0.0036323088591219454, 'size_2': 0.0032368897834166503, 'size_3': 0.004932779180403218, 'size_4': 0.006683005368788465}
# Sequence 274 JSD: {'size_interval': 0.31019740480128727, 'size_2': 0.251878689706743, 'size_3': 0.36709050779199515, 'size_4': 0.42329376809927916}
# Sequence 275 JSD: {'size_interval': 0.02721529748409568, 'size_2': 0.0030231111791132015, 'size_3': 0.007035583687036824, 'size_4': 0.011067840276869023}
# Sequence 276 JSD: {'size_interval': 0.004629025956659975, 'size_2': 0.00010345068197118958, 'size_3': 0.0007989151804758745, 'size_4': 0.0014967875005376613}
# Sequence 277 JSD: {'size_interval': 0.011716772585753842, 'size_2': 0.0011151209512462964, 'size_3': 0.0015769900986079485, 'size_4': 0.0019709645939538015}
# Sequence 278 JSD: {'size_interval': 0.0012427771344481415, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 279 JSD: {'size_interval': 0.139972570003456, 'size_2': 0.053265940823254615, 'size_3': 0.11879880144518538, 'size_4': 0.18096618732155043}
# Sequence 280 JSD: {'size_interval': 0.4054545477896213, 'size_2': 0.37824602806964586, 'size_3': 0.4880913244217315, 'size_4': 0.501400843980254}
# Sequence 281 JSD: {'size_interval': 0.0037818719853640824, 'size_2': 0.0004252947203731131, 'size_3': 0.0006641100361220744, 'size_4': 0.000921818484560927}
# Sequence 282 JSD: {'size_interval': 0.004039513281266233, 'size_2': 0.002593656946297711, 'size_3': 0.004682166417870984, 'size_4': 0.007543215617890777}
# Sequence 283 JSD: {'size_interval': 0.007386671563566604, 'size_2': 0.0042095908323337315, 'size_3': 0.007209207858476065, 'size_4': 0.010722046036378174}
# Sequence 284 JSD: {'size_interval': 0.03249808957896708, 'size_2': 0.02352831580653585, 'size_3': 0.0405625086530746, 'size_4': 0.06949851280084693}
# Sequence 285 JSD: {'size_interval': 0.010859880801389816, 'size_2': 0.00709401055899177, 'size_3': 0.019557160673861557, 'size_4': 0.0520911449108894}
# Sequence 286 JSD: {'size_interval': 0.19634230132030908, 'size_2': 0.2132389773053002, 'size_3': 0.29919465960925173, 'size_4': 0.37275861947764116}
# Sequence 287 JSD: {'size_interval': 0.003670022404557363, 'size_2': 0.00016273066922228074, 'size_3': 0.0003546605593828584, 'size_4': 0.0006671973934472591}
# Sequence 288 JSD: {'size_interval': 0.024616708085632245, 'size_2': 0.01647785526526535, 'size_3': 0.02794083971476, 'size_4': 0.03554562398769156}
# Sequence 289 JSD: {'size_interval': 0.0070620558110077525, 'size_2': 0.006730670333593866, 'size_3': 0.010277385925233919, 'size_4': 0.014047431964926785}
# Sequence 290 JSD: {'size_interval': 0.12718542595734791, 'size_2': 0.24486945022061402, 'size_3': 0.34925511076884197, 'size_4': 0.3922717299833733}
# Sequence 291 JSD: {'size_interval': 0.009930734726406069, 'size_2': 0.004678521405943358, 'size_3': 0.009425586999372826, 'size_4': 0.014887456759884633}
# Sequence 292 JSD: {'size_interval': 0.0005470367371847653, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 293 JSD: {'size_interval': 0.1422028987787457, 'size_2': 0.03886117772158998, 'size_3': 0.07116671473446072, 'size_4': 0.1069983668725072}
# Sequence 294 JSD: {'size_interval': 0.0055441384393224375, 'size_2': 0.0018163564325810266, 'size_3': 0.0031826965828360846, 'size_4': 0.004633189756553431}
# Sequence 295 JSD: {'size_interval': 0.009341197851322527, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 296 JSD: {'size_interval': 0.0036300945460951196, 'size_2': 0.002978057438786739, 'size_3': 0.004535229686858356, 'size_4': 0.006140093047077325}
# Sequence 297 JSD: {'size_interval': 0.0022912002644099165, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 298 JSD: {'size_interval': 0.0032861427706852744, 'size_2': 0.003114922553604909, 'size_3': 0.005195890768938521, 'size_4': 0.007681287600747897}
# Sequence 299 JSD: {'size_interval': 0.3780976398810904, 'size_2': 0.4119864331369506, 'size_3': 0.44623837225644625, 'size_4': 0.46182080124088615}
# Sequence 300 JSD: {'size_interval': 0.009345192546685198, 'size_2': 1.010024277739723e-05, 'size_3': 4.596889751993681e-05, 'size_4': 0.0005182143650957842}
# Sequence 301 JSD: {'size_interval': 0.007642644868190076, 'size_2': 0.004877762362213295, 'size_3': 0.008305338492753977, 'size_4': 0.013328112460850949}
# Sequence 302 JSD: {'size_interval': 0.33180783391940116, 'size_2': 0.4091325168825494, 'size_3': 0.4658913614583103, 'size_4': 0.48042925994279645}
# Sequence 303 JSD: {'size_interval': 0.0035360960016162387, 'size_2': 3.1625292534143146e-05, 'size_3': 0.0003550695500828188, 'size_4': 0.0007051547821440112}
# Sequence 304 JSD: {'size_interval': 0.010230048325251612, 'size_2': 0.0008715512036811554, 'size_3': 0.0016301596504299193, 'size_4': 0.0019272669464273058}
# Sequence 305 JSD: {'size_interval': 0.005327933226706411, 'size_2': 0.0009417965614588091, 'size_3': 0.0024934686924904044, 'size_4': 0.0065345562756103336}
# Sequence 306 JSD: {'size_interval': 0.0031183538017410355, 'size_2': 0.00015070656133577302, 'size_3': 0.000201930216395307, 'size_4': 0.00026573409104085514}
# Sequence 307 JSD: {'size_interval': 0.00797731061562184, 'size_2': 0.0011789939043381824, 'size_3': 0.0030808337461940725, 'size_4': 0.008263461483805606}
# Sequence 308 JSD: {'size_interval': 0.011690607826524231, 'size_2': 0.008552777233871161, 'size_3': 0.015480601082385827, 'size_4': 0.026734867089348833}
# Sequence 309 JSD: {'size_interval': 0.03838457001458432, 'size_2': 0.031527658162654744, 'size_3': 0.05794175100997757, 'size_4': 0.10103661254249742}
# Sequence 310 JSD: {'size_interval': 0.002399114453065096, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 311 JSD: {'size_interval': 0.0013923972084095462, 'size_2': 2.3749779093777173e-05, 'size_3': 3.4761473648895734e-05, 'size_4': 4.519964224073016e-05}
# Sequence 312 JSD: {'size_interval': 0.01450816516604344, 'size_2': 0.009925409238891458, 'size_3': 0.01729848869887602, 'size_4': 0.02319006192020471}
# Sequence 313 JSD: {'size_interval': 0.0253072322866783, 'size_2': 0.002833968030477242, 'size_3': 0.007507592143359712, 'size_4': 0.021346375276713393}
# Sequence 314 JSD: {'size_interval': 0.012543331467728088, 'size_2': 0.025354412337809766, 'size_3': 0.048908634186180085, 'size_4': 0.07377332600144991}
# Sequence 315 JSD: {'size_interval': 0.007705729833190386, 'size_2': 0.0017317408985791738, 'size_3': 0.0030050942328712174, 'size_4': 0.00410928188218903}
# Sequence 316 JSD: {'size_interval': 0.002081168911767108, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 317 JSD: {'size_interval': 0.0049747780130233385, 'size_2': 0.0024523620180550245, 'size_3': 0.004240898959718116, 'size_4': 0.007996337625347131}
# Sequence 318 JSD: {'size_interval': 0.0014147391360752421, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 319 JSD: {'size_interval': 0.007635689215050664, 'size_2': 0.0037544279576111933, 'size_3': 0.01195898423181724, 'size_4': 0.034935730764163224}
# Sequence 320 JSD: {'size_interval': 0.0026456333824588806, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 321 JSD: {'size_interval': 0.051880177057351894, 'size_2': 0.07364576650070706, 'size_3': 0.1126261788122783, 'size_4': 0.19773593639644252}
# Sequence 322 JSD: {'size_interval': 0.27839804665341694, 'size_2': 0.2466709421935057, 'size_3': 0.31287088659706214, 'size_4': 0.3771221699491913}
# Sequence 323 JSD: {'size_interval': 0.012475392517810402, 'size_2': 0.02390063788650603, 'size_3': 0.047383558171154444, 'size_4': 0.07216928116316876}
# Sequence 324 JSD: {'size_interval': 0.004800751816281156, 'size_2': 0.004668225079212551, 'size_3': 0.007043068053104906, 'size_4': 0.009464868871050719}
# Sequence 325 JSD: {'size_interval': 0.016589606379748552, 'size_2': 0.013401219313451413, 'size_3': 0.04283574307379303, 'size_4': 0.11233067780976849}
# Sequence 326 JSD: {'size_interval': 0.003527096846391742, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 327 JSD: {'size_interval': 0.012379643175572781, 'size_2': 0.00013110958245737608, 'size_3': 0.0005209392082240867, 'size_4': 0.0026616802334988223}
# Sequence 328 JSD: {'size_interval': 0.012629249867425953, 'size_2': 0.0016290114094203248, 'size_3': 0.0029757792120033533, 'size_4': 0.014118530225434156}
# Sequence 329 JSD: {'size_interval': 0.0039270203457695664, 'size_2': 0.004421236090081215, 'size_3': 0.007386417424050134, 'size_4': 0.011006413353042595}
# Sequence 330 JSD: {'size_interval': 0.007210273343900083, 'size_2': 0.00273393119641879, 'size_3': 0.004248405496926172, 'size_4': 0.00738977421286398}
# Sequence 331 JSD: {'size_interval': 0.010594185899396794, 'size_2': 0.003978161960173598, 'size_3': 0.00613664030442562, 'size_4': 0.013301690978191142}
# ...
# Sequence 891 JSD: {'size_interval': 0.012547423747512264, 'size_2': 0.0036259294446511735, 'size_3': 0.007254460778770494, 'size_4': 0.010912362326172457}
# Sequence 892 JSD: {'size_interval': 0.3826129634791674, 'size_2': 0.3654310646417407, 'size_3': 0.4525385611169393, 'size_4': 0.46779065554166543}
# Sequence 893 JSD: {'size_interval': 0.004096382794468705, 'size_2': 0.0014983476368377524, 'size_3': 0.0031743728495870972, 'size_4': 0.005042250538205867}
# Sequence 894 JSD: {'size_interval': 0.2681828739259894, 'size_2': 0.281922822304359, 'size_3': 0.3533220243991796, 'size_4': 0.3844430145101885}
# Sequence 895 JSD: {'size_interval': 0.0037581123012504674, 'size_2': 0.001667755678277927, 'size_3': 0.0024819845534156527, 'size_4': 0.0032851279498486026}
# Sequence 896 JSD: {'size_interval': 0.008272867787267569, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 897 JSD: {'size_interval': 0.008394929966810896, 'size_2': 0.00030782689865740964, 'size_3': 0.0015846272511525488, 'size_4': 0.0041860033183776565}
# Sequence 898 JSD: {'size_interval': 0.0023348015961209, 'size_2': 4.7758948901481444e-05, 'size_3': 6.0245353244439135e-05, 'size_4': 6.585148792107856e-05}
# Sequence 899 JSD: {'size_interval': 0.0034220346275858566, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 900 JSD: {'size_interval': 0.010081775215337764, 'size_2': 0.006139782630866993, 'size_3': 0.026699468999042263, 'size_4': 0.05295066369654542}
# Sequence 901 JSD: {'size_interval': 0.005990134597805873, 'size_2': 0.005051851201758164, 'size_3': 0.007592620089722759, 'size_4': 0.01297042342228336}
# Sequence 902 JSD: {'size_interval': 0.22472812876258527, 'size_2': 0.30911033479362693, 'size_3': 0.4087284709063454, 'size_4': 0.4277064244792361}
# Sequence 903 JSD: {'size_interval': 0.0013343308010787286, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 904 JSD: {'size_interval': 0.12561363784121704, 'size_2': 0.15659656859579504, 'size_3': 0.27292146940629636, 'size_4': 0.31939490465116105}
# Sequence 905 JSD: {'size_interval': 0.0061775818638894805, 'size_2': 0.006545493809355684, 'size_3': 0.008055508171697808, 'size_4': 0.009729022987092857}
# Sequence 906 JSD: {'size_interval': 0.006489814320656361, 'size_2': 0.005451283923566537, 'size_3': 0.010964923989851872, 'size_4': 0.016463966042612636}
# Sequence 907 JSD: {'size_interval': 0.13723570443672245, 'size_2': 0.16250564526780667, 'size_3': 0.29446225105766316, 'size_4': 0.3608040634584282}
# Sequence 908 JSD: {'size_interval': 0.011981359795534993, 'size_2': 0.006957068499490847, 'size_3': 0.01087918752292254, 'size_4': 0.01513661375057354}
# Sequence 909 JSD: {'size_interval': 0.01743688588677766, 'size_2': 0.005479113632970614, 'size_3': 0.009386115201207135, 'size_4': 0.012382072579392629}
# Sequence 910 JSD: {'size_interval': 0.04466707603801243, 'size_2': 0.027660776869107017, 'size_3': 0.05555202893299177, 'size_4': 0.08810614798284469}
# Sequence 911 JSD: {'size_interval': 0.004000545732564023, 'size_2': 2.3272973640335774e-07, 'size_3': 5.086176792100693e-07, 'size_4': 9.339786485931124e-07}
# Sequence 912 JSD: {'size_interval': 0.012287349961067904, 'size_2': 4.929700609247031e-06, 'size_3': 6.806555696569056e-05, 'size_4': 0.0007050166503088129}
# Sequence 913 JSD: {'size_interval': 0.041526662583568186, 'size_2': 0.02556646199568136, 'size_3': 0.057560699701118136, 'size_4': 0.09313440410797579}
# Sequence 914 JSD: {'size_interval': 0.00036243041914891275, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 915 JSD: {'size_interval': 0.005452347297865573, 'size_2': 0.0019744591709052626, 'size_3': 0.003148898482273861, 'size_4': 0.00458865776423164}
# Sequence 916 JSD: {'size_interval': 0.002411639744236817, 'size_2': 0.0003693104024263841, 'size_3': 0.000626160128789806, 'size_4': 0.0008428998673902048}
# Sequence 917 JSD: {'size_interval': 0.001540849712931279, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 918 JSD: {'size_interval': 0.16824994431156293, 'size_2': 0.12097191124863654, 'size_3': 0.25231766454284177, 'size_4': 0.33224923964507147}
# Sequence 919 JSD: {'size_interval': 0.005742120768626187, 'size_2': 0.0013063783580597318, 'size_3': 0.0021689541241527084, 'size_4': 0.003202645924596324}
# Sequence 920 JSD: {'size_interval': 0.002569617902705354, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 921 JSD: {'size_interval': 0.24418827151025377, 'size_2': 0.33159254237427904, 'size_3': 0.4028202674629786, 'size_4': 0.41990750913082364}
# Sequence 922 JSD: {'size_interval': 0.0048426967321243, 'size_2': 0.002187747394332099, 'size_3': 0.0065874492137269584, 'size_4': 0.026400940173088666}
# Sequence 923 JSD: {'size_interval': 0.0033292872635429962, 'size_2': 0.002812550229131553, 'size_3': 0.004097729309622777, 'size_4': 0.005375560594544662}
# Sequence 924 JSD: {'size_interval': 0.009660305778775642, 'size_2': 0.00030162267368759863, 'size_3': 0.001743720092323485, 'size_4': 0.0032055112848684013}
# Sequence 925 JSD: {'size_interval': 0.0039248795914622854, 'size_2': 0.0008384137728779194, 'size_3': 0.0011565377546155187, 'size_4': 0.0016501217265904112}
# Sequence 926 JSD: {'size_interval': 0.002879753544864097, 'size_2': 0.001087210713329444, 'size_3': 0.0012769166995120391, 'size_4': 0.002248345897574946}
# Sequence 927 JSD: {'size_interval': 0.03166577300170487, 'size_2': 0.035677146828558465, 'size_3': 0.09876764149091731, 'size_4': 0.19027410258923053}
# Sequence 928 JSD: {'size_interval': 0.009466236150952071, 'size_2': 0.001369995197628824, 'size_3': 0.0022869578497236405, 'size_4': 0.003395452994300048}
# Sequence 929 JSD: {'size_interval': 0.001315394478835454, 'size_2': 0.001141798486742593, 'size_3': 0.0020343825144332546, 'size_4': 0.0028159399785904152}
# Sequence 930 JSD: {'size_interval': 0.13367252892989728, 'size_2': 0.08133216384546704, 'size_3': 0.18123767218646863, 'size_4': 0.26385718435063865}
# Sequence 931 JSD: {'size_interval': 0.004551101187095495, 'size_2': 0.0002091091657284313, 'size_3': 0.0002455817491047453, 'size_4': 0.0008620171789122164}
# Sequence 932 JSD: {'size_interval': 0.002501441336922499, 'size_2': 0.001562792054791344, 'size_3': 0.002189637066581301, 'size_4': 0.0027596813266438755}
# Sequence 933 JSD: {'size_interval': 0.09896861036827348, 'size_2': 0.05153908283104677, 'size_3': 0.12394713144226344, 'size_4': 0.18404238004702206}
# Sequence 934 JSD: {'size_interval': 0.016516176759855113, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 935 JSD: {'size_interval': 0.024935268141376622, 'size_2': 0.011796089834486682, 'size_3': 0.033876952716510304, 'size_4': 0.05712730991460468}
# Sequence 936 JSD: {'size_interval': 0.0253228821578718, 'size_2': 0.011131548214877088, 'size_3': 0.015563465424855729, 'size_4': 0.02567736586807569}
# Sequence 937 JSD: {'size_interval': 0.004952371904834861, 'size_2': 0.0010811987606175284, 'size_3': 0.001541931316696602, 'size_4': 0.0025098981964936607}
# Sequence 938 JSD: {'size_interval': 0.015419589408628625, 'size_2': 0.003449348672930825, 'size_3': 0.010248522597369917, 'size_4': 0.01861846327198889}
# Sequence 939 JSD: {'size_interval': 0.006150321505145941, 'size_2': 0.0001773971779062888, 'size_3': 0.00020398920445528337, 'size_4': 0.0003426050421203139}
# Sequence 940 JSD: {'size_interval': 0.0054885122961247645, 'size_2': 0.0007137950493806691, 'size_3': 0.0046900474957245935, 'size_4': 0.00908870846015462}
# Sequence 941 JSD: {'size_interval': 0.0059132350671591664, 'size_2': 0.0017166844053294768, 'size_3': 0.008104988824110338, 'size_4': 0.024327332440994873}
# Sequence 942 JSD: {'size_interval': 0.006970466859042852, 'size_2': 0.01606994016487022, 'size_3': 0.0307642542674983, 'size_4': 0.04751868256443992}
# Sequence 943 JSD: {'size_interval': 0.01059829474458022, 'size_2': 0.003643460283737593, 'size_3': 0.005486234847701483, 'size_4': 0.01383988806902577}
# Sequence 944 JSD: {'size_interval': 0.0036167682039606876, 'size_2': 0.0021365552968956197, 'size_3': 0.0037606280887930044, 'size_4': 0.005422554451494683}
# Sequence 945 JSD: {'size_interval': 0.11508338167359086, 'size_2': 0.14165729918282322, 'size_3': 0.22215819743990964, 'size_4': 0.2891785640365921}
# Sequence 946 JSD: {'size_interval': 0.007836269372393033, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 947 JSD: {'size_interval': 0.08856217183394999, 'size_2': 0.061536151209560026, 'size_3': 0.12687066591893603, 'size_4': 0.21063971339796364}
# Sequence 948 JSD: {'size_interval': 0.347343263437383, 'size_2': 0.32214325711943076, 'size_3': 0.44405208078158365, 'size_4': 0.45974813046088636}
# Sequence 949 JSD: {'size_interval': 0.3455373986698458, 'size_2': 0.3526230498557974, 'size_3': 0.39169056981009726, 'size_4': 0.40994514500261653}
# Sequence 950 JSD: {'size_interval': 0.023027785634871824, 'size_2': 0.018707596802225723, 'size_3': 0.0448578632522515, 'size_4': 0.07276295572777955}
# Sequence 951 JSD: {'size_interval': 0.11218609099372154, 'size_2': 0.11354230008705951, 'size_3': 0.19426519650731616, 'size_4': 0.27224980597215376}
# Sequence 952 JSD: {'size_interval': 0.2674153700606735, 'size_2': 0.30426707832084754, 'size_3': 0.36126363641361847, 'size_4': 0.40084691368596287}
# Sequence 953 JSD: {'size_interval': 0.0006987527967173403, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 954 JSD: {'size_interval': 0.0022579032902595333, 'size_2': 0.00026065135269141143, 'size_3': 0.00032569532078072753, 'size_4': 0.0003484869180852561}
# Sequence 955 JSD: {'size_interval': 0.06486522929162625, 'size_2': 0.025794963939821947, 'size_3': 0.041898479043281686, 'size_4': 0.07227988998291643}
# Sequence 956 JSD: {'size_interval': 0.06005534468984458, 'size_2': 0.04870416977724069, 'size_3': 0.08519045412651928, 'size_4': 0.11997885871443406}
# Sequence 957 JSD: {'size_interval': 0.020027916310064182, 'size_2': 0.020902017855079738, 'size_3': 0.0586134454702408, 'size_4': 0.09921012410829884}
# Sequence 958 JSD: {'size_interval': 0.010247464403774095, 'size_2': 0.006540336011083031, 'size_3': 0.010674299593835458, 'size_4': 0.015530022995377656}
# Sequence 959 JSD: {'size_interval': 0.0032182302848770506, 'size_2': 0.0019203049100945308, 'size_3': 0.002826660285391755, 'size_4': 0.003786832268174417}
# Sequence 960 JSD: {'size_interval': 0.005595574496563941, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 961 JSD: {'size_interval': 0.0031474388951805714, 'size_2': 0.0007807364221487343, 'size_3': 0.0016072406820528823, 'size_4': 0.00318189443453195}
# Sequence 962 JSD: {'size_interval': 0.24764872857966622, 'size_2': 0.23808255176287285, 'size_3': 0.3416372813538928, 'size_4': 0.3844430145101885}
# Sequence 963 JSD: {'size_interval': 0.14003941261514066, 'size_2': 0.046290746665824695, 'size_3': 0.07982839033741275, 'size_4': 0.11416354400153406}
# Sequence 964 JSD: {'size_interval': 0.00339985929008151, 'size_2': 0.0007526247784654011, 'size_3': 0.003942873177441356, 'size_4': 0.007181338545199724}
# Sequence 965 JSD: {'size_interval': 0.025240191391132247, 'size_2': 0.001905624310519638, 'size_3': 0.003388787799261627, 'size_4': 0.013454665366334169}
# Sequence 966 JSD: {'size_interval': 0.0033174957581886028, 'size_2': 0.0023688482178016693, 'size_3': 0.006084681011530223, 'size_4': 0.012486769426786169}
# Sequence 967 JSD: {'size_interval': 0.05541417227353261, 'size_2': 0.0294160888208359, 'size_3': 0.08395717037202732, 'size_4': 0.1494073641762435}
# Sequence 968 JSD: {'size_interval': 0.014715526039662188, 'size_2': 0.0032770928500004824, 'size_3': 0.0051329651008753235, 'size_4': 0.008812671728769844}
# Sequence 969 JSD: {'size_interval': 0.012086401477741848, 'size_2': 0.0046124538979144085, 'size_3': 0.006981977714981405, 'size_4': 0.009395303510563786}
# Sequence 970 JSD: {'size_interval': 0.3841693909338879, 'size_2': 0.3714562005898493, 'size_3': 0.4640891605494714, 'size_4': 0.4787245538197992}
# Sequence 971 JSD: {'size_interval': 0.0020709011389683308, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 972 JSD: {'size_interval': 0.17253397735413184, 'size_2': 0.10410714942301397, 'size_3': 0.23178664411385502, 'size_4': 0.3306076794414881}
# Sequence 973 JSD: {'size_interval': 0.13401273712873, 'size_2': 0.10001108325705935, 'size_3': 0.17009279529860702, 'size_4': 0.23923752434675213}
# Sequence 974 JSD: {'size_interval': 0.007431831663950318, 'size_2': 0.0008941844957989313, 'size_3': 0.002330539501002118, 'size_4': 0.004523535170389608}
# Sequence 975 JSD: {'size_interval': 0.0024483510839188203, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 976 JSD: {'size_interval': 0.008742651202369122, 'size_2': 0.005448331696715915, 'size_3': 0.023453224029023875, 'size_4': 0.043890872136334455}
# Sequence 977 JSD: {'size_interval': 0.08880584748266095, 'size_2': 0.10206554291900188, 'size_3': 0.18951481497916045, 'size_4': 0.2526978216400644}
# Sequence 978 JSD: {'size_interval': 0.08434898212718032, 'size_2': 0.0792512123466116, 'size_3': 0.09200303279262084, 'size_4': 0.10245900142093914}
# Sequence 979 JSD: {'size_interval': 0.01169301966997671, 'size_2': 0.004704011976984585, 'size_3': 0.009542096667676298, 'size_4': 0.01904580500517389}
# Sequence 980 JSD: {'size_interval': 0.022041182908331493, 'size_2': 0.0019269083399541013, 'size_3': 0.005763028173139748, 'size_4': 0.017649455140917602}
# Sequence 981 JSD: {'size_interval': 0.0074258893462930305, 'size_2': 1.6692673502026944e-05, 'size_3': 0.00043730422328339396, 'size_4': 0.0009108599958880666}
# Sequence 982 JSD: {'size_interval': 0.002852273307892195, 'size_2': 0.0004679559799636287, 'size_3': 0.0009781518995646617, 'size_4': 0.0016109328548567297}
# Sequence 983 JSD: {'size_interval': 0.008915642374139589, 'size_2': 0.007120635573945554, 'size_3': 0.014803364666312149, 'size_4': 0.024482750715996954}
# Sequence 984 JSD: {'size_interval': 0.07584709186061774, 'size_2': 0.053151583981365394, 'size_3': 0.09347703725910024, 'size_4': 0.20305238094765868}
# Sequence 985 JSD: {'size_interval': 0.0010511169506113576, 'size_2': 0.0014164815168838103, 'size_3': 0.0025248085882376143, 'size_4': 0.0039683979290783536}
# Sequence 986 JSD: {'size_interval': 0.016085134154689866, 'size_2': 0.008174195316632183, 'size_3': 0.020228614406390753, 'size_4': 0.04874115587478437}
# Sequence 987 JSD: {'size_interval': 0.16039334643316613, 'size_2': 0.13603862203561257, 'size_3': 0.23486729789266983, 'size_4': 0.30953882972007124}
# Sequence 988 JSD: {'size_interval': 0.0011843094273255022, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 989 JSD: {'size_interval': 0.0013855789369812128, 'size_2': 0.0003345900608377707, 'size_3': 0.0004105110639564215, 'size_4': 0.0004252344733834174}
# Sequence 990 JSD: {'size_interval': 0.046758274333305594, 'size_2': 0.044368325718096444, 'size_3': 0.1061363297410399, 'size_4': 0.16617505003233746}
# Sequence 991 JSD: {'size_interval': 0.0016113016359914425, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}
# Sequence 992 JSD: {'size_interval': 0.0035152966767333267, 'size_2': 0.0015460898556063844, 'size_3': 0.0023618037341257337, 'size_4': 0.0032074280684392118}
# Sequence 993 JSD: {'size_interval': 0.02268986726560696, 'size_2': 0.01694601458151036, 'size_3': 0.05671234303933115, 'size_4': 0.1286710859778739}
# Sequence 994 JSD: {'size_interval': 0.007730249647642652, 'size_2': 0.0015133281364267497, 'size_3': 0.0029794405010995727, 'size_4': 0.005622471430554551}
# Sequence 995 JSD: {'size_interval': 0.01248012654334704, 'size_2': 0.013255612022256261, 'size_3': 0.022987486980610664, 'size_4': 0.03292553163034342}
# Sequence 996 JSD: {'size_interval': 0.008401430729178757, 'size_2': 0.0032924788647123635, 'size_3': 0.004853247872139369, 'size_4': 0.006426163186528117}
# Sequence 997 JSD: {'size_interval': 0.0013814627207692923, 'size_2': 0.0011476347387471416, 'size_3': 0.0019862557986505894, 'size_4': 0.0030796425002462668}
# Sequence 998 JSD: {'size_interval': 0.008347977526666987, 'size_2': 0.0008811532463746516, 'size_3': 0.0023177813724134296, 'size_4': 0.004256855345601041}
# Sequence 999 JSD: {'size_interval': 0.0004021574318707296, 'size_2': 0.0, 'size_3': 0.0, 'size_4': 0.0}

# %%
jsds = pd.DataFrame(jsds)

# %%
for key in jsds.keys():
    print(f'{key}: mean: {jsds[key].mean()}, median: {jsds[key].median()}, p90: {jsds[key].quantile(0.9)}, p95: {jsds[key].quantile(0.95)}, p99: {jsds[key].quantile(0.99)}')
# Out:
# size_interval: mean: 0.04343357499528365, median: 0.008694420875225635, p90: 0.14796114656196227, p95: 0.26659155301721077, p99: 0.3826285277537146
# size_2: mean: 0.03919982898758229, median: 0.0024793791911609875, p90: 0.13660048975033376, p95: 0.28287794586456505, p99: 0.3908552737087098
# size_3: mean: 0.05853032775115767, median: 0.004932467506191716, p90: 0.24744079573731118, p95: 0.3781692646006074, p99: 0.46410718255855976
# size_4: mean: 0.07449789790997467, median: 0.008779793814995239, p90: 0.3204629501221032, p95: 0.41636908257236155, p99: 0.48042925994279645

# %%
for key in jsds.keys():
    print(f'{key}: mean: {jsds[key].mean()}, median: {jsds[key].median()}, p90: {jsds[key].quantile(0.9)}, p95: {jsds[key].quantile(0.95)}, p99: {jsds[key].quantile(0.99)}')
# Out:
# size_interval: mean: 0.0548317159109112, median: 0.01878444758433427, p90: 0.16482003526940397, p95: 0.268804331562431, p99: 0.38460681733337254
# size_2: mean: 0.04462036085837829, median: 0.005882325082381739, p90: 0.16063841680356572, p95: 0.28587929688998953, p99: 0.39784901042032894
# size_3: mean: 0.06880187720820077, median: 0.011257682879155996, p90: 0.27308699170430983, p95: 0.3810706475152146, p99: 0.4640546436905572
# size_4: mean: 0.08952715708343681, median: 0.018529527728655043, p90: 0.35796939462134747, p95: 0.41938744520103655, p99: 0.4972871062818458

# %%
np.argsort(jsds['size_4'].values), np.sort(jsds['size_4'].values)
# Out:
# (array([99, 34, 44, 22, 45, 46, 54, 55, 28, 58, 30,  5,  9, 92, 68, 90, 89,
#         66, 57, 23, 93, 74, 67, 36, 94, 52, 56, 15, 38, 18,  0, 85, 17, 98,
#         40,  4,  3, 33, 41, 80,  1, 61,  2, 81, 87, 95, 64,  7, 86, 51, 37,
#         79, 26, 50, 29, 77, 60, 19, 91, 59, 27, 12, 73, 71, 25, 35, 72, 63,
#         65, 78, 76, 32, 16, 11, 48, 70, 62, 88, 24, 49, 97, 69, 10, 13, 83,
#         96, 42, 47, 84, 82, 31, 43, 75, 21,  8, 39,  6, 20, 14, 53]),
#  array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.37348465e-05, 3.71760920e-05, 1.77514450e-04,
#         3.33676360e-04, 3.79575737e-04, 3.84660777e-04, 4.91131936e-04,
#         6.24186371e-04, 8.52671849e-04, 9.01621571e-04, 9.18920523e-04,
#         1.06582061e-03, 1.47500209e-03, 1.62557183e-03, 1.72066286e-03,
#         1.95447635e-03, 1.99262683e-03, 2.00095969e-03, 2.07356474e-03,
#         2.11161448e-03, 2.16335990e-03, 2.17481764e-03, 2.64285521e-03,
#         2.73573698e-03, 2.93312836e-03, 3.07219170e-03, 3.18098129e-03,
#         3.25768723e-03, 3.29395915e-03, 3.72354603e-03, 3.77036712e-03,
#         3.83812021e-03, 4.55877294e-03, 5.01716002e-03, 5.95232940e-03,
#         6.21574004e-03, 6.35015996e-03, 6.86791278e-03, 6.94897731e-03,
#         7.84853295e-03, 9.39629885e-03, 9.81651541e-03, 1.00329998e-02,
#         1.04406119e-02, 1.07426199e-02, 1.16558345e-02, 1.20799298e-02,
#         1.27169417e-02, 1.36606803e-02, 1.41546335e-02, 1.46165220e-02,
#         1.51838794e-02, 1.67453955e-02, 1.68802270e-02, 1.89758664e-02,
#         2.34103542e-02, 2.67638519e-02, 2.84482851e-02, 2.97271041e-02,
#         3.11056626e-02, 3.65058509e-02, 3.86012150e-02, 4.15599465e-02,
#         4.55285539e-02, 4.90416132e-02, 4.96942229e-02, 5.17817062e-02,
#         5.21228962e-02, 5.87762941e-02, 5.89336835e-02, 5.95649823e-02,
#         6.11208312e-02, 6.36177959e-02, 6.43120608e-02, 6.55997826e-02,
#         6.58319975e-02, 7.52125662e-02, 8.13899899e-02, 8.49043946e-02,
#         8.60296731e-02, 8.67775113e-02, 1.00921757e-01, 1.19279488e-01]))

# %%
size_seq = seqs[8] // n_interval
size_gen = np.array(gens[8]) // n_interval
n_gram_ori = compute_ngram_distribution(size_seq, 2)
n_gram_gen = compute_ngram_distribution(size_gen, 2)

# %%
size_seq, size_gen[0:len(size_seq)]
# Out:
# (array([18, 16, 10, 10,  9, 11, 10, 11,  7, 11, 12,  9, 11, 12, 14, 19, 16,
#         13, 10,  9, 20, 10, 13, 14, 11, 20, 11, 20, 17, 11, 10, 18, 11, 12,
#         14, 11, 18, 10, 20, 11, 10, 20, 21, 17, 10, 11, 11, 11, 11, 10, 11,
#         11, 11, 17, 10, 15, 11, 11, 15, 10, 10,  9,  9,  9, 18]),
#  array([18, 16, 10, 10,  9, 11, 10, 11,  7, 11, 12,  9, 11, 12, 14, 19, 16,
#         13, 11, 11, 16, 13, 14, 11, 20, 11, 20, 17, 11, 10, 18, 11, 10, 11,
#         11, 11, 17, 10, 15, 11, 11, 15, 10, 10,  9, 17, 11, 15, 19, 11, 17,
#         20, 15, 20, 11, 11, 11, 20, 11, 11, 11, 10, 11, 11, 11]))
